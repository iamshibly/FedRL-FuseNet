# %% [markdown]
# # Baseline Backbone Comparison
#
# The full GitHub-viewable version of this experiment is available as Markdown:
#
# [Open 6-arcf-net-baseline-backbone-compare.md](6-arcf-net-baseline-backbone-compare.md)
#
# The Markdown file contains the code, saved outputs, and exported output images.
